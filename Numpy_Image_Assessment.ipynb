# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create an 5 by 5 array where every number is 10
tens_arr = 10 * np.ones(shape=(5, 5))
tens_arr
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
# Get the Random NUmber using seed
np.random.seed(101)

# %%
arr = np.random.randint(low=0, high=100, size=(5, 5))
arr
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
# Get the max and Min value from the aboe array
print (arr.max())
print (arr.min())
# Out:
# 95
# 4

# %%
# Using PIL plot the image
from PIL import Image

# %%
img = Image.open('../Images/Photo2.jpg')
plt.imshow(img)

# %%
img_arr = np.asarray(img)
img_arr
# Out:
# array([[[231, 229, 232],
#         [228, 228, 230],
#         [226, 226, 228],
#         ...,
#         [187, 193, 191],
#         [176, 182, 182],
#         [176, 182, 182]],
#
#        [[224, 223, 228],
#         [224, 223, 228],
#         [221, 222, 226],
#         ...,
#         [180, 186, 184],
#         [177, 183, 181],
#         [176, 182, 180]],
#
#        [[231, 231, 239],
#         [226, 229, 236],
#         [224, 227, 234],
#         ...,
#         [174, 180, 178],
#         [174, 180, 178],
#         [177, 183, 181]],
#
#        ...,
#
#        [[ 24,  15,   6],
#         [ 28,  18,   9],
#         [ 30,  20,  11],
#         ...,
#         [243, 213, 123],
#         [241, 213, 130],
#         [241, 214, 137]],
#
#        [[ 12,   5,   0],
#         [ 24,  15,   6],
#         [ 28,  20,   9],
#         ...,
#         [240, 208, 131],
#         [246, 213, 146],
#         [244, 212, 151]],
#
#        [[ 10,   4,   0],
#         [ 27,  21,   9],
#         [ 34,  26,  15],
# ...

# %%
img_arr.shape
plt.imshow(img_arr)

# %%
img2 = img_arr.copy()

# %%
# Zero Out Red Channel
img2[:,:,0] = 0
plt.imshow(img2)

# %%
# Zero Out Green Channel
img2[:,:,1] = 0
plt.imshow(img2)
